# %% [markdown]
# # # Find the highest salary from nyc jobs

# %% [markdown]
# Using the nyc_jobs file, find the highest maximum salary in the file

# %%
import pandas as pd

jobs_df = pd.read_csv('nyc-jobs.csv')
pd.options.display.max_columns = None
display(jobs_df)

# %%
toilets_df = pd.read_json('https://data.cityofnewyork.us/resource/r27e-u3sy.json')

toilets_df

# %%
jobs_df["Salary Range To"].max()

# %%
jobs_df.to_json('nyc-jobs.json')

# %%
jobs_df.dtypes

# %%
jobs_df.describe(include='all')
# Out:
#         Job Identification                         Agency Posting Type  \
# count          3885.000000                           3885         3885
# unique                 NaN                             53            2
# top                    NaN  DEPT OF HEALTH/MENTAL HYGIENE     Internal
# freq                   NaN                            847         2161
# first                  NaN                            NaN          NaN
# last                   NaN                            NaN          NaN
# mean         354994.821107                            NaN          NaN
# std           38932.102607                            NaN          NaN
# min           87990.000000                            NaN          NaN
# 25%          350897.000000                            NaN          NaN
# 50%          371575.000000                            NaN          NaN
# 75%          376831.000000                            NaN          NaN
# ...

# %%
jobs_df.rename(columns={"Job ID": "Job Identification"})

# %%
jobs_df

# %% [markdown]
# to convert a column to another data type, use the following syntax

# %%
jobs_df["Process Date"] = jobs_df["Process Date"].astype('datetime64')

# %%
jobs_df["Process Date"]

# %% [markdown]
# assign categorical variables to numerical variables

# %%
numerical_job_type_df = pd.get_dummies(jobs_df["Posting Type"])
numerical_job_type_df

# %%
jobs_df["External"] = numerical_job_type_df["External"]
jobs_df

# %%
jobs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3885 entries, 0 to 3884
# Data columns (total 29 columns):
# Job Identification               3885 non-null int64
# Agency                           3885 non-null object
# Posting Type                     3885 non-null object
# # Of Positions                   3885 non-null int64
# Business Title                   3885 non-null object
# Civil Service Title              3885 non-null object
# Title Code No                    3885 non-null object
# Level                            3885 non-null object
# Job Category                     3883 non-null object
# Full-Time/Part-Time indicator    3547 non-null object
# Salary Range From                3885 non-null float64
# Salary Range To                  3885 non-null float64
# Salary Frequency                 3885 non-null object
# Work Location                    3885 non-null object
# Division/Work Unit               3885 non-null object
# ...

# %% [markdown]
# count different values from a column, in this case we will see the different type of residency requirements and how many jobs have each requirement

# %%
jobs_df["Residency Requirement"].value_counts()
# Out:
# New York City residency is generally required within 90 days of appointment. However, City Employees in certain titles who have worked for the City for 2 continuous years may also be eligible to reside in Nassau, Suffolk, Putnam, Westchester, Rockland, or Orange County. To determine if the residency requirement applies to you, please discuss with the agency representative at the time of interview.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      
# ...

# %%
import seaborn as sns
sns.boxplot(x="Posting Type", y="Salary Range To", data=jobs_df)
